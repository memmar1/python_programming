# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def extract():
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
    url = "https://www.impactpool.org/search?q=accountant&commit=search"
    r = requests.get(url,headers)
    return r.status_code
extract()
# Out:
# 200

# %%
def extract():
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
    url = "https://www.impactpool.org/search?q=accountant&commit=search"
    r = requests.get(url,headers)
    soup = BeautifulSoup(r.content, "html.parser")
    return soup
c = extract()

# %%
def transform(soup):
    divs = soup.find_all("div", class_ = "job ip-layout")    
    for item in divs:
        try:
            newpost = item.find("span", class_ = "label label-warning new-job with-margin-right-xs").text
        except:
            newpost = " "
        title = item.find("a").text.strip()
        grade = item.find("div", class_ = "job-grade").text.strip()
        orgnization = item.find("div", class_ = "job-organization").text.strip()
        #close_date = item.find("div", class_= "closing-date soon").text.strip()         """found a challenge here"""
        #duty_station = item.find("i", class_ = "icon fa fa-map-marker").text.strip()    """found a challenge here"""
        #print(newpost, title, grade,orgnization) """for display as am working"""
        Job = { "New_Posts": newpost,
               "Job_Title": title,
               "Level": grade,
               "Company": orgnization
        }
        Joblist.append(Job)
    return
Joblist = []
transform(c)
print(len(Joblist))
# Out:
# 40

# %%
print(Joblist)
# Out:
# [{'New_Posts': ' ', 'Job_Title': 'Accountant', 'Level': 'Mid level - Mid level', 'Company': 'The HALO Trust'}, {'New_Posts': 'NEW', 'Job_Title': 'Accountant', 'Level': 'Mid level - Mid level', 'Company': 'CFCA - Community Foundation for Children and Aging'}, {'New_Posts': ' ', 'Job_Title': 'Assistant (Accounts)', 'Level': 'Administrative support - Administrative Services and Support - Generally no need for Higher Education', 'Company': 'WHO - World Health Organization'}, {'New_Posts': ' ', 'Job_Title': 'ACCOUNTING ASSISTANT', 'Level': 'Administrative support - GS-5, General Service - No need for Higher Education - Locally recruited position', 'Company': 'UNOG - United Nations Office at Geneva'}, {'New_Posts': ' ', 'Job_Title': 'Associate Accountant', 'Level': 'Junior level - P-2, International Professional - Internationally recruited position', 'Company': 'UNOV - United Nations Office at Vienna'}, {'New_Posts': 'NEW', 'Job_Title': 'Accounting Assistant', 'Level': 'Administrative supp
# ...

# %%
df = pd.DataFrame(Joblist)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   New_Posts  40 non-null     object
#  1   Job_Title  40 non-null     object
#  2   Level      40 non-null     object
#  3   Company    40 non-null     object
# dtypes: object(4)
# memory usage: 1.4+ KB

# %%
df
# Out:
#    New_Posts                                          Job_Title  \
# 0                                                    Accountant
# 1        NEW                                         Accountant
# 2                                          Assistant (Accounts)
# 3                                          ACCOUNTING ASSISTANT
# 4                                          Associate Accountant
# 5        NEW                               Accounting Assistant
# 6        NEW                               Accounting Assistant
# 7                                            Project Accountant
# 8                                             Accounting Expert
# 9             Finance & Accounting Associate (Accounts Recei...
# 10                                   Assistant Manager Accounts
# 11                                     Accountant (all genders)
# 12                               Finance Assistant (Accountant)
# 13       NEW                   Account & Administration Officer
# ...
