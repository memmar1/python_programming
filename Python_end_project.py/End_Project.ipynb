# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def extract():
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
    url = "https://www.impactpool.org/search?q=data+analysis&commit=search"
    r = requests.get(url,headers)
    #return r.status_code
    soup = BeautifulSoup(r.content, "html.parser")
    return soup
c = extract()

# %%
def transform(soup):
    divs = soup.find_all("div", class_ = "job ip-layout")    
    for item in divs:
        try:
            newpost = item.find("span", class_ = "label label-warning new-job with-margin-right-xs").text
        except:
            newpost = " "
        title = item.find("a").text.strip()
        grade = item.find("div", class_ = "job-grade").text.strip()
        orgnization = item.find("div", class_ = "job-organization").text.strip()
        #close_date = item.find("div", class_= "closing-date soon").text.strip()         """found a challenge here"""
        #duty_station = item.find("i", class_ = "icon fa fa-map-marker").text.strip()    """found a challenge here"""
        #print(newpost, title, grade,orgnization) """for display as am working"""
        Job = { "New_Posts": newpost,
               "Job_Title": title,
               "Level": grade,
               "Company": orgnization
        }
        Joblist.append(Job)
    return
Joblist = []
transform(c)
print(Joblist)
# Out:
# [{'New_Posts': 'NEW', 'Job_Title': 'INTERN - Data Analysis and Data Management', 'Level': 'Internship - Internship', 'Company': 'UN - United Nations'}, {'New_Posts': 'NEW', 'Job_Title': 'Resource Mobilization data analysis officer', 'Level': 'Volunteer - National Youth - Locally recruited Volunteer', 'Company': 'UNV - United Nations Volunteers'}, {'New_Posts': ' ', 'Job_Title': 'Data analysis – internal workload assessment surveys', 'Level': 'Level not specified - Level not specified', 'Company': 'UNV - United Nations Volunteers'}, {'New_Posts': ' ', 'Job_Title': 'Young Graduate Trainee in Sustainability Data Analysis in Facilities Management', 'Level': 'Level not specified - Level not specified', 'Company': 'ESA - European Space Agency'}, {'New_Posts': ' ', 'Job_Title': 'Consultant - Data Analysis and Annual Reporting, End Violence Against Children (EVAC), 38 Days (May to June 2024), REMOTE, Req#569819', 'Level': 'Consultancy - Consultant - Contractors Agreement', 'Company': 'UNICEF - United Nations Children’s Fund'}, {'New_Posts': ' ', 'Job_Title': 'Data Management Intern (Unpaid)', 'Level': 'Internship - Internship', 'Company': 'IRC - International Rescue Committee'}, {'New_Posts': ' ', 'Job_Title': 'Monitoring & Evaluation Specialist, (P-3), Office of Innovation (Giga), Geneva, Switzerland, #127761 (Temporary Appointment 364 days)', 'Level': 'Mid level - P-3, International Professional - Internationally recruited position', 'Company': 'UNICEF - United Nations Children’s Fund'}, {'New_Posts': 'NEW', 'Job_Title': 'International Scientist – Spatial Data Science', 'Level': 'Level not specified - Level not specified', 'Company': 'CIFOR - Center for International Forestry Research'}, {'New_Posts': 'NEW', 'Job_Title': 'International Scientist - Spatial Data Science', 'Level': 'Level not specified - Level not specified', 'Company': 'ICRAF - The World Agroforestry Centre'}, {'New_Posts': ' ', 'Job_Title': 'Intern - Internal Audit (5446)', 'Level': 'Internship - Internship', 'Company': 'AIIB - Asian Infrastructure Investment Bank'}, {'New_Posts': ' ', 'Job_Title': 'Seconded National Expert', 'Level': 'Administrative support - FG I, Function Group 1, Contract Agent', 'Company': 'EIOPA - European Insurance and Occupational Pensions Authority'}, {'New_Posts': 'NEW', 'Job_Title': 'International MICS Consultant', 'Level': 'Consultancy - Consultant - Contractors Agreement', 'Company': 'UNICEF - United Nations Children’s Fund'}, {'New_Posts': 'NEW', 'Job_Title': 'Procurement Senior Analyst (Internal Candidates Only)', 'Level': 'Junior level - IICA-1, International Individual Contractors Agreement', 'Company': 'UNOPS - United Nations Office for Project Services'}, {'New_Posts': ' ', 'Job_Title': 'MMC Research Specialist - LAC', 'Level': 'Mid level - Mid level', 'Company': 'DRC - Danish Refugee Council'}, {'New_Posts': 'NEW', 'Job_Title': 'Agroecological Systems Analyst', 'Level': 'Level not specified - Level not specified', 'Company': 'ICRAF - The World Agroforestry Centre'}, {'New_Posts': 'NEW', 'Job_Title': 'Agroecological Systems Analyst', 'Level': 'Junior level - Junior', 'Company': 'CIFOR - Center for International Forestry Research'}, {'New_Posts': ' ', 'Job_Title': 'Spring 2024 Data Analytics & Systems Intern', 'Level': 'Internship - Internship', 'Company': 'IRC - International Rescue Committee'}, {'New_Posts': ' ', 'Job_Title': 'Senior Research Associate, AMBIT/Retain6 Research Projects', 'Level': 'Senior level - Managerial Level - Open for both International and National Professionals', 'Company': 'CHAI - Clinton Health Access Initiative'}, {'New_Posts': ' ', 'Job_Title': 'Data Analyst/Report Developer (GHSA)', 'Level': 'Junior level - Junior', 'Company': 'Jhpiego'}, {'New_Posts': ' ', 'Job_Title': 'Lead Waveform Analyst (P-3)', 'Level': 'Mid level - P-3, International Professional - Internationally recruited position', 'Company': 'CTBTO - Comprehensive Nuclear Test Ban Treaty'}, {'New_Posts': ' ', 'Job_Title': 'Seconded National E ...

# %%
df = pd.DataFrame(Joblist)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   New_Posts  40 non-null     object
#  1   Job_Title  40 non-null     object
#  2   Level      40 non-null     object
#  3   Company    40 non-null     object
# dtypes: object(4)
# memory usage: 1.4+ KB

# %%
df
# Out:
#    New_Posts                                          Job_Title  \
# 0        NEW         INTERN - Data Analysis and Data Management
# 1        NEW        Resource Mobilization data analysis officer
# 2             Data analysis – internal workload assessment s...
# 3             Young Graduate Trainee in Sustainability Data ...
# 4             Consultant - Data Analysis and Annual Reportin...
# 5                               Data Management Intern (Unpaid)
# 6             Monitoring & Evaluation Specialist, (P-3), Off...
# 7        NEW     International Scientist – Spatial Data Science
# 8        NEW     International Scientist - Spatial Data Science
# 9                                Intern - Internal Audit (5446)
# 10                                     Seconded National Expert
# 11       NEW                      International MICS Consultant
# 12       NEW  Procurement Senior Analyst (Internal Candidate...
# 13                                MMC Research Specialist - LAC
# 14       NEW                     Agroecological Systems Analyst
# 15       NEW                     Agroecological Systems Analyst
# 16                  Spring 2024 Data Analytics & Systems Intern
# 17            Senior Research Associate, AMBIT/Retain6 Resea...
# 18                         Data Analyst/Report Developer (GHSA)
# 19                                  Lead Waveform Analyst (P-3)
# 20                                     Seconded National Expert
# 21            National Monitoring & Evaluation Officer, at N...
# 22            Young Graduate Trainee in Radiation Hardness A...
# 23                                   MW23148 Research Assistant
# 24            Junior Data Officer (CCCM - Durable Solutions ...
# 25                              HR Specialist, People Analytics
# 26            Senior Information Management Officer (Nationa...
# 27                  Data Officer for Mozambique, based in Pemba
# 28                                      MMC Research Specialist
# 29                                             Economic Analyst
# 30            Data Science Applications for Analyzing Mangro...
# 31            ZA23113 Assistant Research Associate, Applied ...
# 32                           Senior Lead Waveform Analyst (P-4)
# 33       NEW                     MONITORING AND EVALUATION LEAD
# 34       NEW   Junior Monitoring, Evaluation & Learning Officer
# 35       NEW   Junior Monitoring, Evaluation & Learning Officer
# 36                         HR Manager – Compensation & Benefits
# 37                         Finance Officer - Innovative Finance
# 38                             Operations Analysis Officer, P-3
# 39            Senior Officer, Regional Monitoring, Evaluatio...
#
#                                                 Level  \
# 0                             Internship - Internship
# 1   Volunteer - National Youth - Locally recruited...
# 2           Level not specified - Level not specified
# 3           Level not specified - Level not specified
# 4    Consultancy - Consultant - Contractors Agreement
# 5                             Internship - Internship
# 6   Mid level - P-3, International Professional - ...
# 7           Level not specified - Level not specified
# 8           Level not specified - Level not specified
# 9                             Internship - Internship
# 10  Administrative support - FG I, Function Group ...
# 11   Consultancy - Consultant - Contractors Agreement
# 12  Junior level - IICA-1, International Individua...
# 13                              Mid level - Mid level
# 14          Level not specified - Level not specified
# 15                              Junior level - Junior
# 16                            Internship - Internship
# 17  Senior level - Managerial Level - Open for bot...
# 18                              Junior level - Junior
# 19  Mid level - P-3, International Professional - ...
# 20  Administrative support - FG I, Function Group ...
# 21  Junior level - NO-B, National Professional Off...
# 22          Level not specified - Level not specified
# 23  Administrative support - Administrative Servic...
# 24                              Junior level - Junior
# 25  Mid level - IICA-2, International Individual C...
# 26                              Mid level - Mid level
# 27          Level not specified - Level not specified
# 28                              Mid level - Mid level
# 29          Level not specified - Level not specified
# 30          Level not specified - Level not specified
# 31  Administrative support - Administrative Servic...
# 32  Mid level - P-4, International Professional - ...
# 33          Level not specified - Level not specified
# 34                              Junior level - Junior
# 35          Level not specified - Level not specified
# 36                              Mid level - Mid level
# 37          Level not specified - Level not specified
# 38  Mid level - P-3, International Professional - ...
# 39                                     Mid level - X9
#
#                                               Company
# 0                                 UN - United Nations
# 1                     UNV - United Nations Volunteers
# 2                     UNV - United Nations Volunteers
# 3                         ESA - European Space Agency
# 4             UNICEF - United Nations Children’s Fund
# 5                IRC - International Rescue Committee
# 6             UNICEF - United Nations Children’s Fund
# 7   CIFOR - Center for International Forestry Rese...
# 8               ICRAF - The World Agroforestry Centre
# 9         AIIB - Asian Infrastructure Investment Bank
# 10  EIOPA - European Insurance and Occupational Pe...
# 11            UNICEF - United Nations Children’s Fund
# 12  UNOPS - United Nations Office for Project Serv...
# 13                       DRC - Danish Refugee Council
# 14              ICRAF - The World Agroforestry Centre
# 15  CIFOR - Center for International Forestry Rese...
# 16               IRC - International Rescue Committee
# 17            CHAI - Clinton Health Access Initiative
# 18                                            Jhpiego
# 19      CTBTO - Comprehensive Nuclear Test Ban Treaty
# 20                                 EU Careers by EPSO
# 21            UNICEF - United Nations Children’s Fund
# 22                        ESA - European Space Agency
# 23  CIMMYT - International Maize and Wheat Improve...
# 24                                 IMPACT Initiatives
# 25  UNOPS - United Nations Office for Project Serv...
# 26               IRC - International Rescue Committee
# 27                                 IMPACT Initiatives
# 28                       DRC - Danish Refugee Council
# 29                    UNV - United Nations Volunteers
# 30                    UNV - United Nations Volunteers
# 31  CIMMYT - International Maize and Wheat Improve...
# 32      CTBTO - Comprehensive Nuclear Test Ban Treaty
# 33                                               CARE
# 34  CIFOR - Center for International Forestry Rese...
# 35              ICRAF - The World Agroforestry Centre
# 36                  CIP - International Potato Center
# 37             GPE - Global Partnership for Education
# 38      CTBTO - Comprehensive Nuclear Test Ban Treaty
# 39               GGGI - Global Green Growth Institute
